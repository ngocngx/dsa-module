# %%
class Node:
    def __init__(self, value, left = None, right = None):
        self.value = value
        self.left = left
        self.right = right
    
    def __repr__(self):
        return str(self.value)

class BinaryTree:
    def __init__(self, value):
        self.root = Node(value)

    def add_left(self, parent: Node, child: Node):
        parent.left = child

    def add_right(self, parent: Node, child: Node):
        parent.right = child

# %%
a = Node('a')
b = Node('b')
c = Node('c')
d = Node('d')
e = Node('e')

binary_tree = BinaryTree(a)
binary_tree.add_left(a, b)
binary_tree.add_right(a, c)
binary_tree.add_left(b, d)
binary_tree.add_right(b, e)

# %%
class Node:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

    def __repr__(self):
        return str(self.value)


class BinaryTree:
    def __init__(self, root):
        self.root = root

    def add_left(self, parent: Node, child: Node):
        parent.left = child

    def add_right(self, parent: Node, child: Node):
        parent.right = child

    def __str__(self):
        return self.travel(self.root)

    def travel(self, element):
        if element:
            print(element.value, end=' ')
            self.travel(element.left)
            self.travel(element.right)

    # def bi_search(self, element, value):
    #     if element:
    #         if element.value == value:
    #             return True
    #         elif element.value < value:
    #             return self.bi_search(element.right, value)
    #         else:
    #             return self.bi_search(element.left, value)
    #     return False

    def bi_search(self, element):
        temp = self.root

        while temp:
            if temp.value == element:
                return True
            elif temp.value < element:
                temp = temp.right
            elif temp.value > element:
                temp = temp.left
        return False

    def depth(self, root):
        if not root:
            return 0
        elif root.left and root.right:
            return 1 + max(self.depth(root.left), self.depth(root.right))
        elif not root.right:
            return 1 + self.depth(root.left)
        elif not root.left:
            return 1 + self.depth(root.right)


a = Node(7)
b = Node(5)
c = Node(9)
d = Node(1)
e = Node(6)
f = Node(8)
g = Node(10)
h = Node(11)
i = Node(15)

binary_tree = BinaryTree(a)
binary_tree.add_left(a, b)
binary_tree.add_left(b, d)
binary_tree.add_right(b, e)
binary_tree.add_right(a, c)
binary_tree.add_left(c, f)
binary_tree.add_right(c, g)
binary_tree.add_right(g, h)
binary_tree.add_right(h, i)


binary_tree.travel(a)
print('\n')

# print(binary_tree.bi_search(a, 3))
# print(binary_tree.bi_search(1))
print(binary_tree.depth(a))
# Out:
# 7 5 1 6 9 8 10 11 15
#
# 5

# %%
class Empty(Exception):
    pass


class Queue:
    """FIFO Queue implementation using a Python list as underlying storage."""

    def __init__(self):
        """ Create an empty queue """
        self._data = []
        self._size = 0

    def __repr__(self):
        """ Return string representation of the queue """
        return str(self._data)

    def __len__(self):
        """ Return the number of elements in the queue """
        return self._size

    def is_empty(self):
        """ Return True if the queue is empty """
        return self._size == 0

    def enqueue(self, value):
        """ Add an element to the back of queue """
        self._data.append(value)
        self._size += 1

    def dequeue(self):
        """ Remove and return the first element of the queue.
        Raise Empty exception if the queue is empty. """
        if self.is_empty():
            raise Empty('Queue is empty')
        self._size -= 1
        return self._data.pop(0)

    def first(self):
        """ Return (but do not remove) the element at the front of the queue.
        Raise Empty exception if the queue is empty. """
        if self.is_empty():
            raise Empty('Queue is empty')
        return self._data[0]

class Node:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

    def __str__(self):
        return str(self.value)


class BinaryTree:
    def __init__(self, root):
        self.root = root

    def add_left(self, parent: Node, child: Node):
        parent.left = child

    def add_right(self, parent: Node, child: Node):
        parent.right = child

    def breadfirst(self):
        queue = Queue()
        queue.enqueue(self.root)

        while queue:
            p = queue.dequeue()
            print(p, end=' ')
            if p.left:
                queue.enqueue(p.left)
            if p.right:
                queue.enqueue(p.right)


a = Node('a')
b = Node('b')
c = Node('c')
d = Node('d')
e = Node('e')
h = Node('h')
k = Node('k')
g = Node('g')
i = Node('i')

binary_tree = BinaryTree(a)
binary_tree.add_left(a, b)
binary_tree.add_right(a, c)
binary_tree.add_left(b, d)
binary_tree.add_right(b, e)
binary_tree.add_left(e, h)
binary_tree.add_right(e, k)
binary_tree.add_left(c, g)
binary_tree.add_right(c, i)

binary_tree.breadfirst()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 30
#      26     def __str__(self):
#      27         return ', '.join(self.data)
# ---> 30 n4 = Node(4, 'C')
#      31 n5 = Node(5, 'A')
#      32 n6 = Node(6, 'Z')
#
# TypeError: Node() takes no arguments
